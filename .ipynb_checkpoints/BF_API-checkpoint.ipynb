# %%
import betfairlightweight as bflw
import pandas as pd
from pandas.io.json import json_normalize as jn
import os
from dotenv import load_dotenv, find_dotenv
import bz2

# %%
# Set view parameters
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# Set figsize for charting
# plt.rcParams['figure.figsize'] = (16, 8)

# Get login creds
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)

username = os.environ.get('BF_USERNAME')
password = os.environ.get('BF_PASSWORD')
app_delay_key = os.environ.get('API_DELAY_KEY')
certs = '/Users/henry/code/freelance/upwork/04.03_betfair_download/certs'
dl_path = '/Users/henry/code/freelance/upwork/04.03_betfair_download/data'

# %%
trading = bflw.APIClient(username, password, app_key=app_delay_key, certs=certs)

trading.login()

# %%
# for year in [2015, 2016]:
# for month in range(1,13):
file_list = trading.historic.get_file_list(
    'Soccer', 'Basic Plan', 1, 3, 2015, 31, 3, 2015, 
    countries_collection=['GB', 'DE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])

# target_dir = str(year) + '_' + str(month)
target_dir = 'data/' + '2015_03'
os.makedirs(target_dir)

for file in file_list:
    download = trading.historic.download_file(file_path=file, store_directory=os.getcwd() + '/' + target_dir)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in request(self, method, params, session)
#     164         try:
# --> 165             response_data = response.json()
#     166         except ValueError:
#
# /anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#
# /anaconda3/lib/python3.7/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     517             and not use_decimal and not kw):
# --> 518         return _default_decoder.decode(s)
#     519     if cls is None:
#
# /anaconda3/lib/python3.7/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#
# /anaconda3/lib/python3.7/site-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 4 column 1 (char 6)
#
# During handling of the above exception, another exception occurred:
#
# InvalidResponse                           Traceback (most recent call last)
# <ipython-input-15-31e16bb195b4> in <module>
#       3 file_list = trading.historic.get_file_list(
#       4     'Soccer', 'Basic Plan', 1, 3, 2015, 31, 3, 2015,
# ----> 5     countries_collection=['GB', 'DE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])
#       6
#       7 # target_dir = str(year) + '_' + str(month)
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in get_file_list(self, sport, plan, from_day, from_month, from_year, to_day, to_month, to_year, event_id, event_name, market_types_collection, countries_collection, file_type_collection, session)
#     114         params = clean_locals(locals())
#     115         method = 'DownloadListOfFiles'
# --> 116         (response, elapsed_time) = self.request(method, params, session)
#     117         return response
#     118
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in request(self, method, params, session)
#     165             response_data = response.json()
#     166         except ValueError:
# --> 167             raise InvalidResponse(response.text)
#     168
#     169         return response_data, elapsed_time
#
# InvalidResponse: Invalid response received:
#
#
# <!DOCTYPE html>
#
# <html>
# <head>
#     <meta name="viewport" content="width=device-width" />
#     <title>ngErrorRedirect</title>
# </head>
# <body>
#     <div>
#         Error
#     </div>
# </body>
# </html>

# %%
url = 'http://historicdata.betfair.com/api/DownloadListOfFiles'
headers = {'content-type': 'application/json','ssoid': app_delay_key} 
payload = {
    "sport":"Soccer",
    "plan":"Basic Plan",
    "fromDay" : 1,
    "fromMonth": 1,
    "fromYear" : 2016,
    "toDay": 31,
    "toMonth" : 1,
    "toYear": 2016,
    "marketTypesCollection": ["MATCH_ODDS" ],
    "countriesCollection" : ["GB", "DE" ],
    "fileTypeCollection" : ["M"]
}

# %%
r = requests.get(url, headers=headers, params=payload)

# %% [markdown]
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------

# %%
# Log in
trading = bflw.APIClient(username, password, app_key=app_delay_key, certs=certs)
trading.login()

# %%
file_list = trading.historic.get_file_list(
    'Soccer', 'Basic Plan', 1, 1, 2017, 31, 1, 2017,
    countries_collection=['GB', 'DE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])

# for file in file_list:
#     download = trading.historic.download_file(file_path=file)
# Out:
# ---------------------------------------------------------------------------
# StatusCodeError                           Traceback (most recent call last)
# <ipython-input-6-84a3bea77fa4> in <module>
#       1 file_list = trading.historic.get_file_list(
#       2     'Soccer', 'Basic Plan', 1, 1, 2017, 31, 1, 2017,
# ----> 3     countries_collection=['GB', 'DE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])
#       4
#       5 # for file in file_list:
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in get_file_list(self, sport, plan, from_day, from_month, from_year, to_day, to_month, to_year, event_id, event_name, market_types_collection, countries_collection, file_type_collection, session)
#     114         params = clean_locals(locals())
#     115         method = 'DownloadListOfFiles'
# --> 116         (response, elapsed_time) = self.request(method, params, session)
#     117         return response
#     118
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in request(self, method, params, session)
#     161         elapsed_time = (datetime.datetime.utcnow()-date_time_sent).total_seconds()
#     162
# --> 163         check_status_code(response)
#     164         try:
#     165             response_data = response.json()
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/utils.py in check_status_code(response, codes)
#      15     codes = codes or [200]
#      16     if response.status_code not in codes:
# ---> 17         raise StatusCodeError(response.status_code)
#      18
#      19
#
# StatusCodeError: Status code error: 500

# %%
uncompressedData = bz2.BZ2File('1.138807922.bz2').read()

# %%
uncompressedData[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-5aab0e1873d9> in <module>
# ----> 1 uncompressedData[0]
#
# NameError: name 'uncompressedData' is not defined

# %%
trading.historic.get_my_data()
# Out:
# ---------------------------------------------------------------------------
# StatusCodeError                           Traceback (most recent call last)
# <ipython-input-7-91555b2e2170> in <module>
# ----> 1 trading.historic.get_my_data()
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in get_my_data(self, session)
#      30         params = clean_locals(locals())
#      31         method = 'GetMyData'
# ---> 32         (response, elapsed_time) = self.request(method, params, session)
#      33         return response
#      34
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/endpoints/historic.py in request(self, method, params, session)
#     161         elapsed_time = (datetime.datetime.utcnow()-date_time_sent).total_seconds()
#     162
# --> 163         check_status_code(response)
#     164         try:
#     165             response_data = response.json()
#
# /anaconda3/lib/python3.7/site-packages/betfairlightweight/utils.py in check_status_code(response, codes)
#      15     codes = codes or [200]
#      16     if response.status_code not in codes:
# ---> 17         raise StatusCodeError(response.status_code)
#      18
#      19
#
# StatusCodeError: Status code error: 500

# %%
collection_options = trading.historic.get_collection_options('Soccer', 'Basic Plan', 1, 12, 2017, 31, 12, 2017)

# %%
jn(collection_options)
# Out:
#                                  countriesCollection                                 fileTypeCollection                              marketTypesCollection
# 0  [{'name': '', 'count': 1794}, {'name': 'AE', '...  [{'name': 'E', 'count': 3275}, {'name': 'M', '...  [{'name': '', 'count': 3441}, {'name': 'ACCA',...

# %%
jn(collection_options['countriesCollection'])
# Out:
#     count name
# 0    1794
# 1     570   AE
# 2     107   AG
# 3      75   AM
# 4    2926   AR
# 5     351   AT
# 6     627   AU
# 7     328   AZ
# 8     184   BA
# 9     575   BD
# 10   1977   BE
# 11    387   BG
# 12    100   BH
# 13    125   BN
# 14    459   BO
# 15   1726   BR
# 16    557   CH
# 17    420   CL
# 18    153   CO
# 19    174   CR
# 20    479   CS
# 21     74   CY
# 22    413   CZ
# 23   5453   DE
# 24    778   DK
# 25   1329   DZ
# 26    230   EC
# 27   1011   EG
# 28  11136   ES
# 29   3795   FR
# 30  21386   GB
# 31     50   GE
# 32     25   GI
# 33   1965   GR
# 34    125   GT
# 35    715   HK
# 36    200   HN
# 37    350   HR
# 38    450   HU
# 39   3833   IL
# 40   1235   IN
# 41   7530   IT
# 42    450   JM
# 43    175   JO
# 44    656   JP
# 45     25   KH
# 46    193   KW
# 47     25   LI
# 48    175   LU
# 49    920   MA
# 50    151   MK
# 51    523   MT
# 52    447   MX
# 53   3259   NL
# 54     88   NO
# 55     93   NZ
# 56     25   PA
# 57    120   PE
# 58    100   PH
# 59    618   PL
# 60     50   PS
# 61   3662   PT
# 62    200   PY
# 63    284   QA
# 64    933   RO
# 65    698   RU
# 66    550   SA
# 67    255   SI
# 68    200   SK
# 69    125   SV
# 70    275   TN
# 71   2434   TR
# 72     25   TT
# 73    363   UA
# 74     58   US
# 75    343   UY
# 76     25   UZ
# 77    524   VE
# 78      8   ZA

# %%
# Get advance basket data size
basket_size = trading.historic.get_data_size('Soccer', 'Basic Plan', 1, 8, 2017, 31, 8, 2017)
print(basket_size)
# Out:
# {'totalSizeMB': 277, 'fileCount': 178028}

# %%
file_list = trading.historic.get_file_list(
    'Soccer', 'Basic Plan', 1, 12, 2015, 31, 12, 2015,
    countries_collection=['GB', 'DE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])

# %%
for file in file_list[:5]:
    print(file)
#     download = trading.historic.download_file(file_path=file)
#     print(download)
# Out:
# /data/xds/historic/BASIC/28489702/1.137265248.bz2
# /data/xds/historic/BASIC/28489735/1.137266407.bz2
# /data/xds/historic/BASIC/28489786/1.137270391.bz2
# /data/xds/historic/BASIC/28489786/1.137270318.bz2
# /data/xds/historic/BASIC/28499470/1.137562893.bz2
