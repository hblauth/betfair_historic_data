# %%
import betfairlightweight as bflw
import pandas as pd
from pandas.io.json import json_normalize as jn
import os
from dotenv import load_dotenv, find_dotenv
import bz2

# %%
# Set view parameters
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# Set figsize for charting
# plt.rcParams['figure.figsize'] = (16, 8)

# Get login creds
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)

username = os.environ.get('BF_USERNAME')
password = os.environ.get('BF_PASSWORD')
app_delay_key = os.environ.get('API_DELAY_KEY')
certs = '/Users/user/Code/Football/betfair/certs'
dl_path = '/Users/user/Code/Football/betfair/data'

# %%
# Log in
trading = bflw.APIClient(username, password, app_key=app_delay_key, certs=certs)

trading.login()

# %%
file_list = trading.historic.get_file_list(
    'Soccer', 'Basic Plan', 1, 1, 2018, 31, 1, 2018,
    countries_collection=['GB', 'IE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])

for file in file_list:
    print(file)
    download = trading.historic.download_file(file_path=file)
    print(download)
# Out:
# /data/xds/historic/BASIC/28541000/1.138733960.bz2
# 1.138733960.bz2
# /data/xds/historic/BASIC/28526000/1.138274884.bz2
# 1.138274884.bz2
# /data/xds/historic/BASIC/28529000/1.138400456.bz2
# 1.138400456.bz2
# /data/xds/historic/BASIC/28529000/1.138400517.bz2
# 1.138400517.bz2
# /data/xds/historic/BASIC/28537200/1.138616157.bz2
# 1.138616157.bz2
# /data/xds/historic/BASIC/28552300/1.139064343.bz2
# 1.139064343.bz2
# /data/xds/historic/BASIC/28549300/1.138998047.bz2
# 1.138998047.bz2
# /data/xds/historic/BASIC/28527400/1.138322132.bz2
# 1.138322132.bz2
# /data/xds/historic/BASIC/28527400/1.138473119.bz2
# 1.138473119.bz2
# /data/xds/historic/BASIC/28535500/1.138582885.bz2
# 1.138582885.bz2
# /data/xds/historic/BASIC/28537500/1.138631135.bz2
# 1.138631135.bz2
# /data/xds/historic/BASIC/28552700/1.139073296.bz2
# 1.139073296.bz2
# /data/xds/historic/BASIC/28543800/1.138806673.bz2
# 1.138806673.bz2
# /data/xds/historic/BASIC/28543800/1.138806736.bz2
# 1.138806736.bz2
# /data/xds/historic/BASIC/28543900/1.138811285.bz2
# 1.138811285.bz2
# /data/xds/historic/BASIC/28526010/1.138275520.bz2
# 1.138275520.bz2
# /data/xds/historic/BASIC/28527410/1.138322142.bz2

# %%
uncompressedData = bz2.BZ2File('1.140820944.bz2').read()

# %%
uncompressedData
# Out:
# b'{"op":"mcm","clk":"6202692444","pt":1520413583143,"mc":[{"id":"1.140820944","marketDefinition":{"bspMarket":false,"turnInPlayEnabled":false,"persistenceEnabled":false,"marketBaseRate":5.0,"eventId":"28613889","eventTypeId":"1","numberOfWinners":1,"bettingType":"ODDS","marketType":"MATCH_ODDS","marketTime":"2018-03-10T15:00:00.000Z","suspendTime":"2018-03-10T15:00:00.000Z","bspReconciled":false,"complete":true,"inPlay":false,"crossMatching":false,"runnersVoidable":false,"numberOfActiveRunners":3,"betDelay":0,"status":"OPEN","runners":[{"status":"ACTIVE","sortPriority":1,"id":3611091,"name":"Ballinamallard Utd"},{"status":"ACTIVE","sortPriority":2,"id":539987,"name":"Ards"},{"status":"ACTIVE","sortPriority":3,"id":58805,"name":"The Draw"}],"regulators":["MR_INT"],"countryCode":"GB","discountAllowed":true,"timezone":"Europe/London","openDate":"2018-03-10T15:00:00.000Z","version":2097881082,"name":"Match Odds","eventName":"Ballinamallard Utd v Ards"}}]}\n{"op":"mcm","clk":"6209046263","pt":1520492177630,"mc":[{"id":"1.140820944","marketDefinition":{"bspMarket":false,"turnInPlayEnabled":false,"persistenceEnabled":false,"marketBaseRate":5.0,"eventId":"28613889","eventTypeId":"1","numberOfWinners":1,"bettingType":"ODDS","marketType":"MATCH_ODDS","marketTime":"2018-03-10T15:00:00.000Z","suspendTime":"2018-03-10T15:00:00.000Z","bspReconciled":false,"complete":true,"inPlay":false,"crossMatching":true,"runnersVoidable":false,"numberOfActiveRunners":3,"betDelay":0,"status":"OPEN","runners":[{"status":"ACTIVE","sortPriority":1,"id":3611091,"name":"Ballinamallard Utd"},{"status":"ACTIVE","sortPriority":2,"id":539987,"name":"Ards"},{"status":"ACTIVE","sortPriority":3,"id":58805,"name":"The Draw"}],"regulators":["MR_INT"],"countryCode":"GB","discountAllowed":true,"timezone":"Europe/London","openDate":"2018-03-10T15:00:00.000Z","version":2097881082,"name":"Match Odds","eventName":"Ballinamallard Utd v Ards"}}]}\n{"op":"mcm","clk":"6223253449","pt":1520684411322,"mc":[{"id":"1.140820944","rc":[{"ltp":2.36,"id":539987}]}]}\n{"op":"mcm","clk":"6223465156","pt":1520685857584,"mc":[{"id":"1.140820944","rc":[{"ltp":2.34,"id":539987}]}]}\n{"op":"mcm","clk":"6223553951","pt":1520686624631,"mc":[{"id":"1.140820944","rc":[{"ltp":2.16,"id":539987}]}]}\n{"op":"mcm","clk":"6223659368","pt":1520687346205,"mc":[{"id":"1.140820944","rc":[{"ltp":3.6,"id":58805}]}]}\n{"op":"mcm","clk":"6223875753","pt":1520688544430,"mc":[{"id":"1.140820944","rc":[{"ltp":3.65,"id":58805}]}]}\n{"op":"mcm","clk":"6224262893","pt":1520690763931,"mc":[{"id":"1.140820944","rc":[{"ltp":2.28,"id":539987}]}]}\n{"op":"mcm","clk":"6224343377","pt":1520691188899,"mc":[{"id":"1.140820944","rc":[{"ltp":2.26,"id":539987}]}]}\n{"op":"mcm","clk":"6224837702","pt":1520693538026,"mc":[{"id":"1.140820944","rc":[{"ltp":2.34,"id":539987}]}]}\n{"op":"mcm","clk":"6224841522","pt":1520693565997,"mc":[{"id":"1.140820944","rc":[{"ltp":2.18,"id":539987}]}]}\n{"op":"mcm","clk":"6224903358","pt":1520694016945,"mc":[{"id":"1.140820944","marketDefinition":{"bspMarket":false,"turnInPlayEnabled":false,"persistenceEnabled":false,"marketBaseRate":5.0,"eventId":"28613889","eventTypeId":"1","numberOfWinners":1,"bettingType":"ODDS","marketType":"MATCH_ODDS","marketTime":"2018-03-10T15:00:00.000Z","suspendTime":"2018-03-10T15:00:00.000Z","bspReconciled":false,"complete":true,"inPlay":false,"crossMatching":true,"runnersVoidable":false,"numberOfActiveRunners":3,"betDelay":0,"status":"SUSPENDED","runners":[{"status":"ACTIVE","sortPriority":1,"id":3611091,"name":"Ballinamallard Utd"},{"status":"ACTIVE","sortPriority":2,"id":539987,"name":"Ards"},{"status":"ACTIVE","sortPriority":3,"id":58805,"name":"The Draw"}],"regulators":["MR_INT"],"countryCode":"GB","discountAllowed":true,"timezone":"Europe/London","openDate":"2018-03-10T15:00:00.000Z","version":2104403570,"name":"Match Odds","eventName":"Ballinamallard Utd v Ards"}}]}\n{"op":"mcm","clk":"6226458597","pt":1520701118545,"mc":[{"id":"1.140820944","marketDefinition": ...

# %%
trading.historic.get_my_data()
# Out:
# [{'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-04-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-05-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-06-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-07-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-08-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-09-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-10-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-11-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2015-12-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-01-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-02-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-03-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-04-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-05-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-06-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-07-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-08-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-09-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-10-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-11-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2016-12-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-01-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-02-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-03-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-04-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-05-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-06-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-07-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-08-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-09-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-10-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-11-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2017-12-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-01-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-02-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-03-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-04-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-05-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-06-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-07-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-08-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-09-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-10-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-11-01T00:00:00',
#   'purchaseItemId': 25482},
#  {'sport': 'Soccer',
#   'plan': 'Basic Plan',
#   'forDate': '2018-12-01T00:00:00',
#   'purchaseItemId': 25482}]

# %%
collection_options = trading.historic.get_collection_options('Soccer', 'Basic Plan', 1, 1, 2018, 31, 1, 2018)

# %%
jn(collection_options)
# Out:
#                                  countriesCollection                                 fileTypeCollection                              marketTypesCollection
# 0  [{'name': '', 'count': 16621}, {'name': 'AE', ...  [{'name': 'E', 'count': 4818}, {'name': 'M', '...  [{'name': '', 'count': 5067}, {'name': 'AH_ODD...

# %%
jn(collection_options['marketTypesCollection'])
# Out:
#      count                  name
# 0     5067
# 1        9        AH_ODDS_MARKET
# 2     4370       ALT_TOTAL_GOALS
# 3       33         ANYTIME_SCORE
# 4     4397        ASIAN_HANDICAP
# 5       33     BOOKING_MATCH_BET
# 6      200          BOOKING_ODDS
# 7     4700   BOTH_TEAMS_TO_SCORE
# 8     1493           CLEAN_SHEET
# 9      131      CORNER_MATCH_BET
# 10     199           CORNER_ODDS
# 11    5384         CORRECT_SCORE
# 12     686        CORRECT_SCORE2
# 13      40           DAILY_GOALS
# 14      36        DAILY_SPECIALS
# 15    4390         DOUBLE_CHANCE
# 16    4392           DRAW_NO_BET
# 17       4               ET_BTTS
# 18     127      ET_CORRECT_SCORE
# 19       4     ET_FH_OU_GOALS_05
# 20       4     ET_FH_OU_GOALS_15
# 21       4          ET_HALF_TIME
# 22     152          ET_NEXT_GOAL
# 23     124        ET_OU_GOALS_05
# 24     126        ET_OU_GOALS_15
# 25       4        ET_OU_GOALS_25
# 26       4        ET_OU_GOALS_35
# 27     128            EXTRA_TIME
# 28     886       FIRST_GOAL_ODDS
# 29     209     FIRST_GOAL_SCORER
# 30    4392   FIRST_HALF_GOALS_05
# 31    4391   FIRST_HALF_GOALS_15
# 32    4391   FIRST_HALF_GOALS_25
# 33      33   FIRST_HALF_TEAM_A_1
# 34      33   FIRST_HALF_TEAM_B_1
# 35      33      GOAL_BOTH_HALVES
# 36    4521             HALF_TIME
# 37    4365   HALF_TIME_FULL_TIME
# 38    4519       HALF_TIME_SCORE
# 39     136  HALF_WITH_MOST_GOALS
# 40       6              HANDICAP
# 41     164    HAT_TRICKED_SCORED
# 42      33       LAST_GOALSCORER
# 43    5424            MATCH_ODDS
# 44     356   MATCH_ODDS_AND_BTTS
# 45     174  MATCH_ODDS_AND_OU_25
# 46      33  MATCH_ODDS_AND_OU_35
# 47       5  MATCH_ODDS_UNMANAGED
# 48       4     METHOD_OF_VICTORY
# 49     743           ODD_OR_EVEN
# 50      54            OVER_UNDER
# 51    5386         OVER_UNDER_05
# 52     201  OVER_UNDER_105_CORNR
# 53     132  OVER_UNDER_135_CORNR
# 54    5383         OVER_UNDER_15
# 55    5425         OVER_UNDER_25
# 56      33   OVER_UNDER_25_CARDS
# 57    5387         OVER_UNDER_35
# 58      33   OVER_UNDER_35_CARDS
# 59    5383         OVER_UNDER_45
# 60      87   OVER_UNDER_45_CARDS
# 61    5078         OVER_UNDER_55
# 62      33   OVER_UNDER_55_CORNR
# 63    5072         OVER_UNDER_65
# 64      33   OVER_UNDER_65_CARDS
# 65    4396         OVER_UNDER_75
# 66    4390         OVER_UNDER_85
# 67     135   OVER_UNDER_85_CORNR
# 68     356         PENALTY_TAKEN
# 69      21        QUICKBET_5M_00
# 70      21        QUICKBET_5M_05
# 71      21        QUICKBET_5M_10
# 72      21        QUICKBET_5M_15
# 73      21        QUICKBET_5M_20
# 74      21        QUICKBET_5M_25
# 75      21        QUICKBET_5M_30
# 76      21        QUICKBET_5M_35
# 77      21        QUICKBET_5M_40
# 78      21        QUICKBET_5M_45
# 79      21        QUICKBET_5M_50
# 80      21        QUICKBET_5M_55
# 81      20        QUICKBET_5M_60
# 82      21        QUICKBET_5M_65
# 83      21        QUICKBET_5M_70
# 84      21        QUICKBET_5M_75
# 85      20        QUICKBET_5M_80
# 86      20        QUICKBET_5M_85
# 87     127            SCORE_CAST
# 88     206           SENDING_OFF
# 89     126          SHOWN_A_CARD
# 90       8               SPECIAL
# 91    4397              TEAM_A_1
# 92     349              TEAM_A_2
# 93     343              TEAM_A_3
# 94      33  TEAM_A_OVER_UNDER_05
# 95      33  TEAM_A_OVER_UNDER_15
# 96      33  TEAM_A_OVER_UNDER_25
# 97       1         TEAM_A_PEN_01
# 98       1         TEAM_A_PEN_02
# 99       1         TEAM_A_PEN_03
# 100      1         TEAM_A_PEN_04
# 101      1         TEAM_A_PEN_05
# 102      1         TEAM_A_PEN_06
# 103      1         TEAM_A_PEN_07
# 104      1         TEAM_A_PEN_08
# 105      1         TEAM_A_PEN_09
# 106      1         TEAM_A_PEN_10
# 107      1         TEAM_A_PEN_11
# 108      1         TEAM_A_PEN_12
# 109      1         TEAM_A_PEN_13
# 110      1         TEAM_A_PEN_14
# 111      1         TEAM_A_PEN_15
# 112      1         TEAM_A_PEN_16
# 113      1         TEAM_A_PEN_17
# 114      1         TEAM_A_PEN_18
# 115      1         TEAM_A_PEN_19
# 116      1         TEAM_A_PEN_20
# 117    888     TEAM_A_WIN_TO_NIL
# 118   4396              TEAM_B_1
# 119    345              TEAM_B_2
# 120    342              TEAM_B_3
# 121     33  TEAM_B_OVER_UNDER_05
# 122     33  TEAM_B_OVER_UNDER_15
# 123     33  TEAM_B_OVER_UNDER_25
# 124      1         TEAM_B_PEN_01
# 125      1         TEAM_B_PEN_02
# 126      1         TEAM_B_PEN_03
# 127      1         TEAM_B_PEN_04
# 128      1         TEAM_B_PEN_05
# 129      1         TEAM_B_PEN_06
# 130      1         TEAM_B_PEN_07
# 131      1         TEAM_B_PEN_08
# 132      1         TEAM_B_PEN_09
# 133      1         TEAM_B_PEN_10
# 134      1         TEAM_B_PEN_11
# 135      1         TEAM_B_PEN_12
# 136      1         TEAM_B_PEN_13
# 137      1         TEAM_B_PEN_14
# 138      1         TEAM_B_PEN_15
# 139      1         TEAM_B_PEN_16
# 140      1         TEAM_B_PEN_17
# 141      1         TEAM_B_PEN_18
# 142      1         TEAM_B_PEN_19
# 143      1         TEAM_B_PEN_20
# 144    886     TEAM_B_WIN_TO_NIL
# 145    237      TEAM_TOTAL_GOALS
# 146    190            TO_QUALIFY
# 147    191              TO_SCORE
# 148    127    TO_SCORE_2_OR_MORE
# 149    371  TO_SCORE_BOTH_HALVES
# 150    127     TO_SCORE_HATTRICK
# 151    882           TOTAL_GOALS
# 152   1488       WIN_BOTH_HALVES
# 153     66       WIN_FROM_BEHIND
# 154     66              WIN_HALF
# 155    159               WINCAST
# 156    155        WINNING_MARGIN

# %%
# Get advance basket data size
basket_size = trading.historic.get_data_size('Soccer', 'Basic Plan', 1, 1, 2018, 31, 1, 2018)
print(basket_size)
# Out:
# {'totalSizeMB': 250, 'fileCount': 135174}

# %%
file_list = trading.historic.get_file_list(
    'Soccer', 'Basic Plan', 1, 8, 2018, 31, 9, 2018,
    countries_collection=['GB', 'IE'], market_types_collection=['MATCH_ODDS'], file_type_collection=['M'])

for file in file_list:
    print(file)
    download = trading.historic.download_file(file_path=file)
    print(download)
# Out:
# /data/xds/historic/BASIC/28823244/1.146146447.bz2
# 1.146146447.bz2
# /data/xds/historic/BASIC/28824255/1.146165371.bz2
# 1.146165371.bz2
# /data/xds/historic/BASIC/28825432/1.146195410.bz2
# 1.146195410.bz2
# /data/xds/historic/BASIC/28825433/1.146195501.bz2
# 1.146195501.bz2
# /data/xds/historic/BASIC/28825431/1.146195319.bz2
# 1.146195319.bz2
# /data/xds/historic/BASIC/28825531/1.146197947.bz2
# 1.146197947.bz2
# /data/xds/historic/BASIC/28820718/1.146100775.bz2
# 1.146100775.bz2
# /data/xds/historic/BASIC/28810510/1.145836522.bz2
# 1.145836522.bz2
# /data/xds/historic/BASIC/28810511/1.145836646.bz2
# 1.145836646.bz2
# /data/xds/historic/BASIC/28818304/1.146047545.bz2
# 1.146047545.bz2
# /data/xds/historic/BASIC/28818319/1.146048797.bz2
# 1.146048797.bz2
# /data/xds/historic/BASIC/28828447/1.146260382.bz2
# 1.146260382.bz2
# /data/xds/historic/BASIC/28818827/1.146053637.bz2
# 1.146053637.bz2
# /data/xds/historic/BASIC/28828454/1.146260565.bz2
# 1.146260565.bz2
# /data/xds/historic/BASIC/28824472/1.146173927.bz2
# 1.146173927.bz2
# /data/xds/historic/BASIC/28824470/1.146173719.bz2
# 1.146173719.bz2
# /data/xds/historic/BASIC/28826252/1.146210931.bz2
# 1.146210931.bz2
# /data/xds/historic/BASIC/28826251/1.146210840.bz2
# 1.146210840.bz2
# /data/xds/historic/BASIC/28824474/1.146174134.bz2
# 1.146174134.bz2
# /data/xds/historic/BASIC/28826253/1.146211022.bz2
# 1.144865035.bz2
# /data/xds/historic/BASIC/28775039/1.144865490.bz2
# 1.144865490.bz2
# /data/xds/historic/BASIC/28775189/1.144870993.bz2
# 1.144870993.bz2
# /data/xds/historic/BASIC/28774959/1.144861258.bz2
# 1.144861258.bz2
# /data/xds/historic/BASIC/28774956/1.144861549.bz2
# 1.144861549.bz2
# /data/xds/historic/BASIC/28774945/1.144861840.bz2
# 1.144861840.bz2
# /data/xds/historic/BASIC/28774946/1.144861749.bz2
# 1.144861749.bz2
# /data/xds/historic/BASIC/28774963/1.144861076.bz2
# 1.144861076.bz2
# /data/xds/historic/BASIC/28774957/1.144861440.bz2
# 1.144861440.bz2
# /data/xds/historic/BASIC/28774971/1.144860985.bz2
# 1.144860985.bz2
# /data/xds/historic/BASIC/28828214/1.146375516.bz2
# 1.146375516.bz2
# /data/xds/historic/BASIC/28828139/1.146375615.bz2
# 1.146375615.bz2
# /data/xds/historic/BASIC/28829855/1.146309794.bz2
# 1.146309794.bz2
# /data/xds/historic/BASIC/28829949/1.146316826.bz2
# 1.146316826.bz2
# /data/xds/historic/BASIC/28827931/1.146244222.bz2
# 1.146244222.bz2
# /data/xds/historic/BASIC/28829849/1.146309334.bz2
# 1.146309334.bz2
# /data/xds/historic/BASIC/28774972/1.144861167.bz2
# 1.144861167.bz2
# /data/xds/historic/BASIC/28775068/1.144864440.bz2
# 1.144864440.bz2
# /data/xds/historic/BASIC/28775089/1.144867319.bz2
# 1.144867319.bz2
# /data/xds/historic/BASIC/28831160/1.146355083.bz2
# 1.146355083.bz2
# /data/xds/historic/BASIC/28831161/1.146355091.bz2
# 1.146355091.bz2
# /data/xds/historic/BASIC/28831162/1.146355099.bz2
# 1.146355099.bz2
# /data/xds/historic/BASIC/28831159/1.146355075.bz2
# 1.146355075.bz2
# /data/xds/historic/BASIC/28775008/1.144865804.bz2
# 1.144865804.bz2
# /data/xds/historic/BASIC/28824477/1.146174341.bz2
# 1.146174341.bz2
# /data/xds/historic/BASIC/28775136/1.144868342.bz2
# 1.144868342.bz2
# /data/xds/historic/BASIC/28832988/1.146380628.bz2
# 1.146380628.bz2
# /data/xds/historic/BASIC/28820092/1.146087393.bz2
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# ProtocolError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-89-c624ac681742> in <module>
#       5 for file in file_list:
#       6     print(file)
# ----> 7     download = trading.historic.download_file(file_path=file)
#       8     print(download)
#
# /anaconda3/lib/python3.6/site-packages/betfairlightweight/endpoints/historic.py in download_file(self, file_path, store_directory)
#     132             params={'filePath': file_path},
#     133             headers=self.headers,
# --> 134             stream=True,
#     135         )
#     136         with open(local_filename, 'wb') as f:
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
